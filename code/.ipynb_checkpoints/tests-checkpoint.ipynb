# %% [markdown]
# ### Ce notebook contient les expérimentations effectuées afin d'evaluer les performances de chacune des stratégie.

# %%
import numpy as np
from matplotlib import pyplot as plt
# %load_ext autoreload
# %autoreload 2
import dice_battle_seq as dice_seq
import dice_battle_sim as dice_sim
import print_dice 
from scipy.signal import savgol_filter
np.set_printoptions(suppress=True)

# %% [markdown]
# ### Performances de la stratégie Optimale face aux autres stratégies

# %% [markdown]
# #### En faisant varier le nombre de points à atteindre pour gagner une partie

# %%
N = np.arange(0,500,2)+10
D = 10
P = dice_seq.probabilities(D)
N1b, r1b = dice_seq.expected_rewards(dice_seq.optimal_strategy,dice_seq.blind_strategy,500,N,D,P)
N1b, r2b = dice_seq.expected_rewards(dice_seq.optimal_strategy,dice_seq.random_strategy,500,N,D,P)
N1b, r3b = dice_seq.expected_rewards(dice_seq.optimal_strategy,dice_seq.optimal_strategy,500,N,D,P)

# %%
plt.rcdefaults()
fig, ax = plt.subplots()
y1 = savgol_filter(r1b,51,3)
y2 = savgol_filter(r2b,51,3)
y3 = savgol_filter(r3b,51,3)
ax.plot(N1b, y1, 'b')
ax.plot(N1b,y2, 'r-')
ax.plot(N1b,y3, 'g')
ax.plot(N1b, r1b, label='vs blind')
ax.plot(N1b,r2b, label='vs random')
ax.plot(N1b,r3b, label='vs optimal')
ax.set_xlabel("Nombre de points à atteindre pour gagner la partie (N)")
ax.set_ylabel('esperance de gain')
ax.set_title("Esperance de gain du joueur optimal lorsqu'il entame la partie avec D=10")
plt.legend()
fig.savefig('optVSall_first_N.png')

# %% [markdown]
# #### En faisant varier le nombre de points à atteindre pour gagner une partie

# %%
D = np.arange(1,101)
N = 100
D1a, d1b = dice_seq.expected_rewards_D(dice_seq.optimal_strategy,dice_seq.blind_strategy,500,N,D)
_, d2b = dice_seq.expected_rewards_D(dice_seq.optimal_strategy,dice_seq.random_strategy,500,N,D)
_, d3b = dice_seq.expected_rewards_D(dice_seq.optimal_strategy,dice_seq.optimal_strategy,500,N,D)

# %%
plt.rcdefaults()
fig, ax = plt.subplots()
ax.plot(D1a, d1b, label='vs blind')
ax.plot(D1a,d2b, label='vs random')
ax.plot(D1a,d3b, label='vs optimal')
ax.set_xlabel("Nombre maximum de dés qu'un joueur peut lancer (D)")
ax.set_ylabel('esperance de gain')
ax.set_title("Esperance de gain du joueur optimal lorsqu'il entame la partie avec N=100")
plt.legend()

# %% [markdown]
# ### Performances de la stratégie Aveugle face aux autres stratégies

# %% [markdown]
# #### En faisant varier le nombre de points à atteindre pour gagner une partie

# %%
N = np.arange(0,500,2)+10
D = 10
P = dice_seq.probabilities(D)
N1b, r1b = dice_seq.expected_rewards(dice_seq.blind_strategy,dice_seq.blind_strategy,500,N,D,P)
N1b, r2b = dice_seq.expected_rewards(dice_seq.blind_strategy,dice_seq.random_strategy,500,N,D,P)
N1b, r3b = dice_seq.expected_rewards(dice_seq.blind_strategy,dice_seq.optimal_strategy,500,N,D,P)

# %%
plt.rcdefaults()
fig, ax = plt.subplots()
y1 = savgol_filter(r1b,51,3)
y2 = savgol_filter(r2b,51,3)
y3 = savgol_filter(r3b,51,3)
ax.plot(N1b, y1, 'b')
ax.plot(N1b,y2, 'r-')
ax.plot(N1b,y3, 'g')
ax.plot(N1b, r1b, label='vs blind')
ax.plot(N1b,r2b, label='vs random')
ax.plot(N1b,r3b, label='vs optimal')
ax.set_xlabel("Nombre de points à atteindre pour gagner la partie (N)")
ax.set_ylabel('esperance de gain')
ax.set_title("Esperance de gain du joueur blind lorsqu'il entame la partie avec D=10")
plt.legend()

# %% [markdown]
# #### En faisant varier le nombre de points à atteindre pour gagner une partie

# %%
D = np.arange(1,101)
N = 100
D1a, c1b = dice_seq.expected_rewards_D(dice_seq.blind_strategy,dice_seq.blind_strategy,500,N,D)
_, c2b = dice_seq.expected_rewards_D(dice_seq.blind_strategy,dice_seq.random_strategy,500,N,D)
_, c3b = dice_seq.expected_rewards_D(dice_seq.blind_strategy,dice_seq.optimal_strategy,500,N,D)

# %%
plt.rcdefaults()
fig, ax = plt.subplots()
ax.plot(D1a, c1b, label='vs blind')
ax.plot(D1a,c2b, label='vs random')
ax.plot(D1a,c3b, label='vs optimal')
ax.set_xlabel("Nombre maximum de dés qu'un joueur peut lancer (D)")
ax.set_ylabel('esperance de gain')
ax.set_title("Esperance de gain du joueur blind lorsqu'il entame la partie N=100")
plt.legend()

# %% [markdown]
# ### Performances de la stratégie Random face aux autres stratégies

# %%
N = np.arange(0,500,2)+10
D = 10
P = dice_seq.probabilities(D)
N1b, r1b = dice_seq.expected_rewards(dice_seq.random_strategy,dice_seq.blind_strategy,500,N,D,P)
N1b, r2b = dice_seq.expected_rewards(dice_seq.random_strategy,dice_seq.random_strategy,500,N,D,P)
N1b, r3b = dice_seq.expected_rewards(dice_seq.random_strategy,dice_seq.optimal_strategy,500,N,D,P)

# %%
plt.rcdefaults()
fig, ax = plt.subplots()
y1 = savgol_filter(r1b,51,3)
y2 = savgol_filter(r2b,51,3)
y3 = savgol_filter(r3b,51,3)
ax.plot(N1b, y1, 'b')
ax.plot(N1b,y2, 'r-')
ax.plot(N1b,y3, 'g')
ax.plot(N1b, r1b, label='vs blind')
ax.plot(N1b,r2b, label='vs random')
ax.plot(N1b,r3b, label='vs optimal')
ax.set_xlabel("Nombre de points à atteindre pour gagner la partie (N)")
ax.set_ylabel('esperance de gain')
ax.set_title("Esperance de gain du joueur random lorsqu'il entame la partie avec D=10")
plt.legend()
